# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sys
import socket 
if 'cluster' in socket.gethostname():
    sys.path.append('/resnick/groups/encephalus/jyzhao/Scalable_GPs_jz/create_building_inventory/BrailsPlusPlus')
else:
    sys.path.append('/Users/jinyanzhao/Desktop/Caltech/Permian_Basin/CyberShake/RemoteMountPoint/BrailsPlusPlus')

from brails.utils import ArcgisAPIServiceHelper

# %%
orig_region = gpd.read_file('./risk_region.geojson')
# orig_region = orig_region.to_crs(epsg=32711)

# %%
# FEMA USA Structure API url
API_ENDPOINT = ('https://services2.arcgis.com/FiaPA4ga0iQKduv3/ArcGIS/'
                'rest/services/USA_Structures_View/FeatureServer/0/query')
api_tools = ArcgisAPIServiceHelper(API_ENDPOINT)
api_tools.get_element_counts_polygon(orig_region['geometry'].values.tolist()[0])
# Out:
# 4208

# %%
api_tools.max_elements_per_cell
# Out:
# 2000

# %%
polygon_list = orig_region['geometry'].values.tolist()
def stop_condition(polygon_list):
    """
    Stop condition for the recursive function.
    """
    # test if all polygons has the number of elements less than 1 api call
    for polygon in polygon_list:
        
    return len(polygon_list) == 1
# Out:
#   Cell In[10], line 9
#     return len(polygon_list) == 1
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7
