# %%
import os
import numpy as np
import h5py
import sys
sys.path.append("/resnick/groups/enceladus/jyzhao/Scalable_GPs_jz/regression_gpytorch/src")
from training_utils.utils import read_hdf5, read_hdf5_with_site_id, str2bool

# %%
test_data_training_site_file = "../regression_gpytorch/output/formatted_data/testing_4179_eqs/training_sites_testing_eqs_2.00_ASK14_4179_eqs_1_var_per_eq.h5"
test_data_testing_site_file = "../regression_gpytorch/output/formatted_data/testing_4179_eqs/testing_sites_testing_eqs_2.00_ASK14_4179_eqs_1_var_per_eq.h5"

# %%
_, train_y, _ = read_hdf5_with_site_id(test_data_training_site_file)
_, test_y, _ = read_hdf5_with_site_id(test_data_testing_site_file)

# %%
np.std(np.hstack((train_y, test_y)))
# Out:
# 0.6750772
