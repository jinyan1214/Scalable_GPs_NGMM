# %%
import os
import sys
import numpy as np
sys.path.append("/resnick/groups/enceladus/jyzhao/Scalable_GPs_jz/regression_gpytorch/src")
from training_utils.utils import read_hdf5_with_site_id

# %%
formatted_data_dir = "/resnick/groups/enceladus/jyzhao/Scalable_GPs_jz/regression_gpytorch/output/formatted_data"
TrTr_path = os.path.join(formatted_data_dir, "training_4179_eqs", "training_sites_training_eqs_2.00_ASK14_4179_eqs_1_var_per_eq.h5")
x_trtr, y_trtr, site_id_trtr = read_hdf5_with_site_id(TrTr_path)
print(f"Number of records in training set: {x_trtr.shape[0]}")
print(np.sqrt(np.mean(y_trtr**2)))
# Out:
# Number of records in training set: 920694
# 0.70084167

# %%
TrTe_path = os.path.join(formatted_data_dir, "training_4179_eqs", "testing_sites_training_eqs_2.00_ASK14_4179_eqs_1_var_per_eq.h5")
x_trte, y_trte, site_id_trte = read_hdf5_with_site_id(TrTe_path)
print(f"Number of records in testing set: {x_trte.shape[0]}")
print(np.sqrt(np.mean(y_trte**2)))
# Out:
# Number of records in testing set: 228850
# 0.70391256

# %%
TeTr_path = os.path.join(formatted_data_dir, "testing_4179_eqs", "training_sites_testing_eqs_2.00_ASK14_4179_eqs_1_var_per_eq.h5")
x_tetr, y_tetr, site_id_tetr = read_hdf5_with_site_id(TeTr_path)
print(f"Number of records in training set for testing eqs: {x_tetr.shape[0]}")
print(np.sqrt(np.mean(y_tetr**2)))
TeTe_path = os.path.join(formatted_data_dir, "testing_4179_eqs", "testing_sites_testing_eqs_2.00_ASK14_4179_eqs_1_var_per_eq.h5")
x_tete, y_tete, site_id_tete = read_hdf5_with_site_id(TeTe_path)
print(f"Number of records in testing set for testing eqs: {x_tete.shape[0]}")
print(np.sqrt(np.mean(y_tete**2)))
# Out:
# Number of records in training set for testing eqs: 919086
# 0.70101225
# Number of records in testing set for testing eqs: 228446
# 0.70257086

# %%
x_trtr.shape[0] + x_trte.shape[0] + x_tetr.shape[0] + x_tete.shape[0]
# Out:
# 2297076

# %%
1-0.387/0.701, 1-0.443/0.704, 1-0.405/0.701, 1-0.455/0.703
# Out:
# (0.4479315263908701,
#  0.37073863636363635,
#  0.42225392296718967,
#  0.3527738264580369)
